# %% [markdown]
# <a href="https://www.kaggle.com/code/aminulislamamin/spam-email-detection-exploratory-data-analysis?scriptVersionId=324884746" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(f"\n📂 {dirname}")
    for filename in filenames:
        print("   └──", filename)
# Out:
# 📂 /kaggle/input
#
# 📂 /kaggle/input/datasets
#
# 📂 /kaggle/input/datasets/aminulislamamin
#
# 📂 /kaggle/input/datasets/aminulislamamin/spam-email-detection-dataset-for-deep-learning
#    └── lingSpam.csv
#    └── enronSpamSubset.csv
#    └── spam_email_dataset.csv
#    └── emails.csv
#    └── completeSpamAssassin.csv

# %%
# Find all CSV files automatically
csv_files = []

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if filename.endswith('.csv'):
            full_path = os.path.join(dirname, filename)
            csv_files.append(full_path)

print("CSV Files Found:")
for f in csv_files:
    print(f)

# Load all datasets
datasets = {}

for f in csv_files:
    name = os.path.basename(f).replace('.csv', '')
    datasets[name] = pd.read_csv(f)

print("\nLoaded Datasets:")
print(list(datasets.keys()))
# Out:
# CSV Files Found:
# /kaggle/input/datasets/aminulislamamin/spam-email-detection-dataset-for-deep-learning/lingSpam.csv
# /kaggle/input/datasets/aminulislamamin/spam-email-detection-dataset-for-deep-learning/enronSpamSubset.csv
# /kaggle/input/datasets/aminulislamamin/spam-email-detection-dataset-for-deep-learning/spam_email_dataset.csv
# /kaggle/input/datasets/aminulislamamin/spam-email-detection-dataset-for-deep-learning/emails.csv
# /kaggle/input/datasets/aminulislamamin/spam-email-detection-dataset-for-deep-learning/completeSpamAssassin.csv
#
# Loaded Datasets:
# ['lingSpam', 'enronSpamSubset', 'spam_email_dataset', 'emails', 'completeSpamAssassin']

# %%
for name, df in datasets.items():
    print("="*60)
    print(name)
    print(df.head())
    print("\nShape:", df.shape)
# Out:
# ...
# lingSpam
#    Unnamed: 0                                               Body  Label
# 0           0  Subject: great part-time or summer job !\n \n ...      1
# 1           1  Subject: auto insurance rates too high ?\n \n ...      1
# 2           2  Subject: do want the best and economical hunti...      1
# 3           3  Subject: email 57 million people for $ 99\n \n...      1
# 4           4  Subject: do n't miss these !\n \n attention ! ...      1
#
# Shape: (2605, 3)
# ...
# enronSpamSubset
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2469        2469
# 1          5063        5063
# 2         12564       12564
# 3          2796        2796
# 4          1468        1468
#
#                                                 Body  Label
# 0  Subject: stock promo mover : cwtd\n * * * urge...      1
# 1  Subject: are you listed in major search engine...      1
# 2  Subject: important information thu , 30 jun 20...      1
# 3  Subject: = ? utf - 8 ? q ? bask your life with...      1
# ...

# %%
final_dataset = datasets['spam_email_dataset']

final_dataset.head()
# Out:
#    email_id           subject  \
# 0         0     Weekly Report
# 1         1    Project Update
# 2         2    🔥WIN BIG NOW!!
# 3         3    🔥WIN BIG NOW!!
# 4         4  Meeting Reminder
#
#                                           email_text  num_words  \
# 0  budget review - Statement our I claim world st...         19
# 1  team sync - President series today already. In...         18
# 2  win free urgent offer limited limited urgent u...         19
# 3  guarantee click now cash offer click now guara...         16
# 4  team sync - Significant property hotel not add...         18
#
#    num_characters  num_exclamation_marks  num_links  has_suspicious_link  \
# 0             114                      0          2                    0
# 1             114                      0          7                    0
# 2             126                      0          4                    1
# 3             101                      0          7                    1
# ...
